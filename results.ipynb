# %% [markdown]
# # PROJECT - Results and charts

# %%
import matplotlib.pyplot as plt

#3 loops of Student only
#lr=0.0001 for Student
#Adam optimizer with loss=Categorical Crossentropy
#lr=0.001 for 1st 80 epochs of teacher training, and 0.0001 for 81-100 epochs for 1st run of teacher


rate=[0.1,0.2,0.5,0.75,1,2.5,5,7.5,9] #unlabeled to labeled

#MODEL RESNET20
#Accuracies:
#Supervised model on labeled data always uses data augmentation
#Student model has a Dropout(0.5) on the penultimate layer
#If DA, the Student model also uses data augmentation
#If NDA, the Student model does not use data augmentation
#HN for House Numbers dataset
#CIFAR for CIFAR10 dataset
#Labeled size=5000
#We will try soft labels first, then hard labels, then hard labels with probability threshold

###
HN_5000_DA_supervised=0.9005
HN_5000_DA=[0.9058, 0.906, 0.9088, 0.9072, 0.9105, 0.9123, 0.9124, 0.9153, 0.9176]

supervised=[HN_5000_DA_supervised for i in range(len(rate))]
plt.plot(rate, HN_5000_DA )
plt.plot(rate, supervised,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Accuracy as a function of rate - Data augmentation for Student')
plt.show()


###
HN_5000_NDA_supervised=0.8994 #not equal to the one above just because we relaunched it from scratch. Random Initial Weights have an influence
HN_5000_NDA=[0.9183,0.9206,0.9224,0.9185,0.917,0.9194,0.9191,0.9207,0.9162]

supervised2=[HN_5000_NDA_supervised for i in range(len(rate))]
plt.plot(rate, HN_5000_NDA )
plt.plot(rate, supervised2,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Accuracy as a function of rate - No data augmentation for Student')
plt.show()


###
CIFAR_5000_DA_supervised=0.7441
CIFAR_5000_DA=[0.7471,0.7514,0.7397,0.7395,0.739,0.7103,0.704,0.6922,0.6823]

supervised3=[CIFAR_5000_DA_supervised for i in range(len(rate))]
plt.plot(rate, CIFAR_5000_DA )
plt.plot(rate, supervised3,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Accuracy as a function of rate - Data augmentation for Student')
plt.show()


###
CIFAR_5000_NDA_supervised=0.7635
CIFAR_5000_NDA=[0.7571,0.7595,0.7596,0.7622,0.7613,0.7672,0.7707,0.7755,0.7726]

supervised4=[CIFAR_5000_NDA_supervised for i in range(len(rate))]
plt.plot(rate, CIFAR_5000_NDA )
plt.plot(rate, supervised4,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Accuracy as a function of rate - No data augmentation for Student')
plt.show()


#Simple model (used in Milestone)
SM_CIFAR_5000_NDA_supervised=0.6729
SM_CIFAR_5000_NDA=[0.6911, 0.695, 0.6942, 0.6931, 0.6952, 0.6855, 0.689, 0.6874, 0.6904]

supervised5=[SM_CIFAR_5000_NDA_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_NDA )
plt.plot(rate, supervised5,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - No data augmentation for Student')
plt.show()

SM_CIFAR_5000_DA_supervised=0.6851
SM_CIFAR_5000_DA=[0.6878, 0.6816, 0.6733, 0.6685, 0.6588, 0.6357, 0.6, 0.5849, 0.5816]

supervised6=[SM_CIFAR_5000_DA_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_DA )
plt.plot(rate, supervised6,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - Data augmentation for Student')
plt.show()

#checking sensitivity to number of Student loops
#Now trying with a loop of 10
#Simple model on CIFAR. One with DA. One with NDA


SM_CIFAR_5000_DA_10loops_supervised=0.6916
SM_CIFAR_5000_DA_10loops=[0.7116, 0.71, 0.6929, 0.6867, 0.6837, 0.6291, 0.5723, 0.5065, 0.4708]

supervised7=[SM_CIFAR_5000_DA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_DA_10loops )
plt.plot(rate, supervised7,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - Data augmentation for Student - 10 loops')
plt.show()

SM_CIFAR_5000_NDA_10loops_supervised=0.6985
SM_CIFAR_5000_NDA_10loops=[0.7228, 0.7186, 0.716, 0.7142, 0.7216, 0.7118, 0.7059, 0.6973, 0.6941]

supervised8=[SM_CIFAR_5000_NDA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_NDA_10loops )
plt.plot(rate, supervised8,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - No data augmentation for Student - 10 loops')
plt.show()


#Checking sensitivity to lr. Now choosing lr=0.001. with 3 loops

SM_CIFAR_5000_DA_LR10_supervised=0.6838
SM_CIFAR_5000_DA_LR10=[0.6994, 0.6945, 0.6972, 0.6668, 0.6728, 0.6516, 0.6319, 0.62, 0.629]


supervised9=[SM_CIFAR_5000_DA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_DA_LR10 )
plt.plot(rate, supervised9,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - Data augmentation for Student - LR=0.001')
plt.show()



SM_CIFAR_5000_NDA_LR10_supervised=0.6847
SM_CIFAR_5000_NDA_LR10=[0.6818, 0.6835, 0.6937, 0.6834, 0.6903, 0.685, 0.6947, 0.6954, 0.6785]

supervised10=[SM_CIFAR_5000_NDA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_NDA_LR10 )
plt.plot(rate, supervised10,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Accuracy as a function of rate - No data augmentation for Student - LR=0.001')
plt.show()

#With Resnet lr=0.001
CIFAR_5000_NDA_LR10_supervised=0.7537
CIFAR_5000_NDA_LR10=[0.6919, 0.6791, 0.6818, 0.6319, 0.7088, 0.6858, 0.6983, 0.7439, 0.7064]

supervised10=[CIFAR_5000_NDA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, CIFAR_5000_NDA_LR10 )
plt.plot(rate, supervised10,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Accuracy as a function of rate - No data augmentation for Student - LR=0.001')
plt.show()

CIFAR_5000_DA_LR10_supervised=0.7495
CIFAR_5000_DA_LR10=[0.696, 0.6887, 0.7217, 0.7216, 0.7209, 0.6916, 0.6454, 0.5934, 0.6139]

supervised11=[CIFAR_5000_DA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, CIFAR_5000_DA_LR10 )
plt.plot(rate, supervised11,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Accuracy as a function of rate - Data augmentation for Student - LR=0.001')
plt.show()

HN_5000_NDA_LR10_supervised=0.9004
HN_5000_NDA_LR10=[0.9013, 0.9019, 0.8118, 0.897, 0.8794, 0.8762, 0.8971, 0.9046, 0.9173]

supervised12=[HN_5000_NDA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, HN_5000_NDA_LR10 )
plt.plot(rate, supervised12,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Accuracy as a function of rate - No data augmentation for Student - LR=0.001')
plt.show()

HN_5000_DA_LR10_supervised=0.9006
HN_5000_DA_LR10=[0.8641, 0.8667, 0.8844, 0.8815, 0.8863, 0.8812, 0.8964, 0.9067, 0.8907]

supervised13=[HN_5000_DA_LR10_supervised for i in range(len(rate))]
plt.plot(rate, HN_5000_DA_LR10 )
plt.plot(rate, supervised13,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Accuracy as a function of rate - Data augmentation for Student - LR=0.001')
plt.show()


##Test1
#3 loops with DA

Test1_CIFAR_DA_3_supervised=0.9068
Test1_CIFAR_DA_3=[0.8222,0.825,0.834,0.837,0.8425,0.8107,0.6692,0.7645,0.7935]

supervised14=[Test1_CIFAR_DA_3_supervised for i in range(len(rate))]
plt.plot(rate, Test1_CIFAR_DA_3 )
plt.plot(rate, supervised14,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test1 - CIFAR - Accuracy as a function of rate - Data augmentation for Student - 3 loops, LR=0.001')
plt.show()

Test1_HN_DA_3_supervised=0.9572
Test1_HN_DA_3=[0.9471,0.9433,0.9447,0.934,0.9395,0.9296,0.9382,0.9295,0.9241]

supervised15=[Test1_HN_DA_3_supervised for i in range(len(rate))]
plt.plot(rate, Test1_HN_DA_3 )
plt.plot(rate, supervised15,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test1 - HN - Accuracy as a function of rate - Data augmentation for Student - 3 loops, LR=0.0001')
plt.show()

### Now Results with 10 loops and lr=0.0001

Resnet_HN_5000_DA_10loops_supervised=0.9011
Resnet_HN_5000_DA_10loops=[0.9023,0.9027,0.9046,0.9029,0.9012,0.9044,0.9027, 0.8965, 0.9032]
rate2=[0.1,0.2,0.5,0.75,1,2.5,5,7.5,9]

supervised16=[Resnet_HN_5000_DA_10loops_supervised for i in range(len(rate2))]
plt.plot(rate2, Resnet_HN_5000_DA_10loops )
plt.plot(rate2, supervised16,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

Resnet_HN_5000_NDA_10loops_supervised=0.9024
Resnet_HN_5000_NDA_10loops=[0.9203,0.9167,0.9174,0.9199,0.9135,0.9202,0.9212,0.92, 0.9242]
rate3=[0.1,0.2,0.5,0.75,1,2.5,5,7.5,9]

supervised17=[Resnet_HN_5000_NDA_10loops_supervised for i in range(len(rate3))]
plt.plot(rate3, Resnet_HN_5000_NDA_10loops )
plt.plot(rate3, supervised17,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - No data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

Resnet_CIFAR_5000_DA_10loops_supervised=0.7545
Resnet_CIFAR_5000_DA_10loops=[0.7477,0.7466,0.7448,0.7254,0.7235,0.7095,0.6577,0.6165]
rate4=[0.1,0.2,0.5,0.75,1,2.5,5,7.5]

supervised18=[Resnet_CIFAR_5000_DA_10loops_supervised for i in range(len(rate4))]
plt.plot(rate4, Resnet_CIFAR_5000_DA_10loops )
plt.plot(rate4, supervised18,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

Resnet_CIFAR_5000_NDA_10loops_supervised=0.7469
Resnet_CIFAR_5000_NDA_10loops=[0.7367,0.744,0.7414,0.7403,0.7326,0.7362, 0.7279,0.744,0.7442]
rate5=[0.1,0.2,0.5,0.75,1,2.5,5,7.5,9]

supervised19=[Resnet_CIFAR_5000_NDA_10loops_supervised for i in range(len(rate5))]
plt.plot(rate5, Resnet_CIFAR_5000_NDA_10loops )
plt.plot(rate5, supervised19,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - No data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

SM_CIFAR_5000_DA_10loops_supervised=0.6895
SM_CIFAR_5000_DA_10loops=[0.6998,0.697,0.6922,0.673,0.6769,0.622,0.5684,0.5198,0.4632]


supervised20=[SM_CIFAR_5000_DA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_DA_10loops )
plt.plot(rate, supervised20,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - Data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

SM_CIFAR_5000_NDA_10loops_supervised=0.6883
SM_CIFAR_5000_NDA_10loops=[0.7164,0.7139,0.713,0.7141,0.7137,0.7123,0.7023,0.7,0.695]


supervised21=[SM_CIFAR_5000_NDA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_5000_NDA_10loops )
plt.plot(rate, supervised21,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - CIFAR - No data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

SM_HN_5000_DA_10loops_supervised=0.8859
SM_HN_5000_DA_10loops=[0.9014,0.9025,0.9067,0.9073,0.9058,0.9117,0.9147,0.9151,0.9096]

supervised22=[SM_HN_5000_DA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_HN_5000_DA_10loops )
plt.plot(rate, supervised22,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - HN - Data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

SM_HN_5000_NDA_10loops_supervised=0.8813
SM_HN_5000_NDA_10loops=[0.9071,0.9106,0.9127,0.9113,0.9121,0.9133,0.9154,0.9153,0.9179]

supervised23=[SM_HN_5000_NDA_10loops_supervised for i in range(len(rate))]
plt.plot(rate, SM_HN_5000_NDA_10loops )
plt.plot(rate, supervised23,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple Model - Test2 - HN - No data augmentation for Student - 10 loops, LR=0.0001')
plt.show()

##Test 1 with lr=0.0001 and 6 loops

Test1_CIFAR_NDA_6_supervised=0.9099
Test1_CIFAR_NDA_6=[0.9039,0.9024,0.9012,0.901,0.9029,0.8991,0.8997,0.9043,0.897]

supervised24=[Test1_CIFAR_NDA_6_supervised for i in range(len(rate))]
plt.plot(rate, Test1_CIFAR_NDA_6 )
plt.plot(rate, supervised24,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test1 - CIFAR - No data augmentation for Student - 6 loops, LR=0.0001')
plt.show()

Test1_HN_NDA_6_supervised=0.962
Test1_HN_NDA_6=[0.9574,0.9602,0.9575,0.9603,0.9601,0.96,0.9607,0.9588,0.962]
rate6=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5,9]

supervised25=[Test1_HN_NDA_6_supervised for i in range(len(rate6))]
plt.plot(rate6, Test1_HN_NDA_6 )
plt.plot(rate6, supervised25,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test1 - HN - No data augmentation for Student - 6 loops, LR=0.0001')
plt.show()

#####NOW HARD LABELS##########
#All test2, 100 epochs, 3 loops, lr=0.0001

Restnet_CIFAR_NDA_hard_supervised=0.7509
Restnet_CIFAR_NDA_hard=[0.748, 0.757, 0.7456,0.7422,0.7479,0.7446,0.7487,0.7445]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised26=[Restnet_CIFAR_NDA_hard_supervised for i in range(len(rate))]
plt.plot(rate, Restnet_CIFAR_NDA_hard)
plt.plot(rate, supervised26,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - No data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()


Restnet_CIFAR_DA_hard_supervised=0.7605
Restnet_CIFAR_DA_hard=[0.7548,0.7442,0.7461,0.7484,0.7368,0.7289,0.7118,0.723]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised29=[Restnet_CIFAR_DA_hard_supervised for i in range(len(rate))]
plt.plot(rate, Restnet_CIFAR_DA_hard)
plt.plot(rate, supervised29,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - Data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()


Restnet_HN_NDA_hard_supervised=0.9033
Restnet_HN_NDA_hard=[0.9197,0.9156,0.9145,0.9139,0.9149,0.9097,0.9104,0.9105]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised27=[Restnet_HN_NDA_hard_supervised for i in range(len(rate))]
plt.plot(rate, Restnet_HN_NDA_hard)
plt.plot(rate, supervised27,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - No data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()

Restnet_HN_DA_hard_supervised=0.9027
Restnet_HN_DA_hard=[0.9070,0.9053,0.9037,0.9015,0.9064,0.9068,0.9119,0.9125]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised28=[Restnet_HN_DA_hard_supervised for i in range(len(rate))]
plt.plot(rate, Restnet_HN_DA_hard)
plt.plot(rate, supervised28,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - Data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()


SM_CIFAR_NDA_hard_supervised=0.6889
SM_CIFAR_NDA_hard=[0.7093,0.7097,0.7096,0.7071,0.7023,0.7032,0.7049,0.7064]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised30=[SM_CIFAR_NDA_hard_supervised for i in range(len(rate))]
plt.plot(rate, SM_CIFAR_NDA_hard)
plt.plot(rate, supervised30,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple CNN - Test2 - CIFAR - No data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()

SM_HN_NDA_hard_supervised=0.8803
SM_HN_NDA_hard=[0.9047, 0.9051,0.9059,0.906,0.9071,0.9085,0.9095,0.9125]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised31=[SM_HN_NDA_hard_supervised for i in range(len(rate))]
plt.plot(rate, SM_HN_NDA_hard)
plt.plot(rate, supervised30,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Simple CNN - Test2 - HN - No data augmentation for Student - 3 loops, LR=0.0001-Hard labels')
plt.show()


#####HARD LABELS with probabilities -- only take images where prediction proba is above a certain given threshold#####

Resnet_CIFAR_NDA_hard_60_supervised=0.7553
Resnet_CIFAR_NDA_hard_60=[0.7572, 0.7521,0.7524,0.7529,0.7506, 0.7566, 0.7591, 0.7548]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised32=[Resnet_CIFAR_NDA_hard_60_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_CIFAR_NDA_hard_60)
plt.plot(rate, supervised32,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.6')
plt.show()

Resnet_CIFAR_NDA_hard_75_supervised=0.7607
Resnet_CIFAR_NDA_hard_75=[0.7564, 0.7587, 0.7631, 0.7632, 0.7658, 0.7637, 0.768, 0.7624]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised33=[Resnet_CIFAR_NDA_hard_75_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_CIFAR_NDA_hard_75)
plt.plot(rate, supervised33,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.75')
plt.show()

Resnet_CIFAR_NDA_hard_85_supervised=0.7477
Resnet_CIFAR_NDA_hard_85=[0.7531, 0.7504, 0.7539, 0.7536, 0.7514,0.7523, 0.7562, 0.7624]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised34=[Resnet_CIFAR_NDA_hard_85_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_CIFAR_NDA_hard_85)
plt.plot(rate, supervised34,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - CIFAR - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.85')
plt.show()

Resnet_HN_NDA_hard_60_supervised=0.9068
Resnet_HN_NDA_hard_60=[0.921, 0.9219, 0.9229, 0.9219, 0.9235, 0.9197, 0.9195, 0.9177]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised35=[Resnet_HN_NDA_hard_60_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_HN_NDA_hard_60)
plt.plot(rate, supervised35,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.6')
plt.show()

Resnet_HN_NDA_hard_75_supervised=0.901
Resnet_HN_NDA_hard_75=[0.9216, 0.9182, 0.9201, 0.915, 0.9173, 0.9183, 0.9168, 0.9115]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised36=[Resnet_HN_NDA_hard_75_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_HN_NDA_hard_75)
plt.plot(rate, supervised36,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.75')
plt.show()

Resnet_HN_NDA_hard_85_supervised=0.9013
Resnet_HN_NDA_hard_85=[0.9205, 0.9186, 0.9219, 0.919, 0.9188, 0.9235, 0.92, 0.9215]
rate=[0.1,0.2,0.5,0.75,1,2.5,5, 7.5]

supervised37=[Resnet_HN_NDA_hard_85_supervised for i in range(len(rate))]
plt.plot(rate, Resnet_HN_NDA_hard_85)
plt.plot(rate, supervised37,'r')
plt.xlabel('Rate')
plt.ylabel('Accuracy top 1')
plt.title('Resnet - Test2 - HN - NDA - 3 loops, LR=0.0001-Hard labels-proba=0.85')
plt.show()
